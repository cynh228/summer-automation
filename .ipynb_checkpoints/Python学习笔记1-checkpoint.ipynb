# %% [markdown]
# # 📘 2026-07-20 Python 与 Git 学习笔记
#
# ## 今天学到的技能
# 1. **Python 基础**：`print()`、`input()`、`if/else`、`while`。
# 2. **写了第一个游戏**：猜数字。
# 3. **Git 提交**：把代码推送到 GitHub。
# 4. **Jupyter Notebook**：从今天起用 `.ipynb` 记录所有学习内容。

# %%
print("Hello from Jupyter！")
# 可以验证你的猜数字逻辑
secret = 42
guess = int(input("猜一个数字: "))  # 运行后会弹出输入框
if guess == secret:
    print("太棒了！")
else:
    print("再试试！")
# Out:
# Hello from Jupyter！
# 猜一个数字:  40
# 再试试！
